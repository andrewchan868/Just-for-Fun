# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewchan868/Just-for-Fun/blob/main/username_serach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clone the repo
# !git clone https://github.com/soxoj/maigret
# !pip3 install -r /content/maigret/requirements.txt
# Out:
# Cloning into 'maigret'...
# remote: Enumerating objects: 3874, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 3874 (delta 14), reused 17 (delta 7), pack-reused 3843
# Receiving objects: 100% (3874/3874), 5.26 MiB | 20.54 MiB/s, done.
# Resolving deltas: 100% (2720/2720), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 161 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 193 kB 46.7 MB/s
# ...
#      |████████████████████████████████| 829 kB 47.5 MB/s
# ...
#      |████████████████████████████████| 112 kB 60.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 84 kB/s
# ...
#      |████████████████████████████████| 133 kB 40.5 MB/s
# ...
#      |████████████████████████████████| 6.9 MB 38.0 MB/s
# ...
#      |████████████████████████████████| 121 kB 53.0 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 58.8 MB/s
# ...

# %%
# help
# !python3 /content/maigret/maigret.py --help
# Out:
# usage: maigret.py
#        [-h]
#        [--version]
#        [--timeout TIMEOUT]
#        [--retries RETRIES]
#        [-n CONNECTIONS]
#        [--no-recursion]
#        [--no-extracting]
#        [--id-type {username,yandex_public_id,gaia_id,vk_id,ok_id,wikimapia_uid,steam_id,uidme_uguid,yelp_userid}]
#        [--db DB_FILE]
#        [--cookies-jar-file COOKIE_FILE]
#        [--ignore-ids IGNORED_IDS]
#        [--folderoutput PATH]
#        [--proxy PROXY_URL]
#        [--tor-proxy TOR_PROXY_URL]
#        [--i2p-proxy I2P_PROXY_URL]
#        [--with-domains]
#        [-a]
#        [--top-sites N]
#        [--tags TAGS]
#        [--site SITE_NAME]
#        [--use-disabled-sites]
#        [--parse URL]
#        [--submit URL]
#        [--self-check]
#        [--stats]
#        [--print-not-found]
#        [--print-errors]
#        [--verbose]
#        [--info]
#        [--debug]
#        [--no-color]
#        [--no-progressbar]
#        [-T]
#        [-C]
#        [-H]
# ...

# %%
# search
# !python3 /content/maigret/maigret.py andrewchan868 -a
# Out:
# [-] Starting a search on top 2798 sites from the Maigret database...
# [*] Checking username andrewchan868 on:
# [+] GitHubGist [GitHub]: https://gist.github.com/andrewchan868
# [+] Twitch: https://www.twitch.tv/andrewchan868
#  ├─id: 153880685
#  ├─username: andrewchan868
#  ├─fullname: andrewchan868
#  ├─image: https://static-cdn.jtvnw.net/user-default-pictures-uv/ead5c8b2-a4c9-4724-b1dd-9f00b46cbd3d-profile_image-150x150.png
#  └─likes_count: 0
# [+] YouTube: https://www.youtube.com/andrewchan868
# [+] YouTube User: https://www.youtube.com/andrewchan868
# [+] GitHub: https://github.com/andrewchan868
#  ├─uid: 66477660
#  ├─image: https://avatars.githubusercontent.com/u/66477660?v=4
#  ├─created_at: 2020-06-05T13:15:22Z
#  ├─location: Hong Kong, Singapore
#  ├─follower_count: 0
#  ├─following_count: 3
#  ├─fullname: Andrew Chan
#  ├─public_gists_count: 0
#  ├─public_repos_count: 22
#  └─bio: readme.md
# [+] TradingView: https://www.tradingview.com/u/andrewchan868
# ...
